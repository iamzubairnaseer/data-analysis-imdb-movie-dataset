# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('./imdb-data/IMDB-Movie-Data.csv')

# %% [markdown]
# # Analysis Data

# %% [markdown]
# # Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# # Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# # Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1000, 12)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %% [markdown]
# # Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# # Null Values In The Dataset

# %%
print(f"is there any missing values in dataset? {"YES" if data.isnull().values.any() else "NO"}")
# Out:
# is there any missing values in dataset? YES

# %%
data.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
per_column_missing_values = data.isnull().sum() * 100 / len(data)
per_column_missing_values
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# # Drop All The Missing Values

# %%
# axis=0 => drop rows which contain missing values
# axis=1 => drop columns which contain missing values
# inplace=True => to modify the existing dataset
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %%
# to remove duplicate values
data.drop_duplicates()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # Overall Statistics About The DataFrame

# %%
data.describe() # displays statistics only for the numerical columns
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# categorical as well as numerical
data.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count    838.000000       838                      838
# unique          NaN       837                      189
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     485.247017       NaN                      NaN
# std      286.572065       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      238.250000       NaN                      NaN
# 50%      475.500000       NaN                      NaN
# 75%      729.750000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                 838           838
# unique                                                838           524
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# ...

# %% [markdown]
# # Title of The Movie Having Runtime >= 180 Minutes

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Runtime (Minutes)']
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 993     97
# 994     88
# 996     94
# 997     98
# 999     87
# Name: Runtime (Minutes), Length: 838, dtype: int64

# %%
data['Runtime (Minutes)']>=180
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993    False
# 994    False
# 996    False
# 997    False
# 999    False
# Name: Runtime (Minutes), Length: 838, dtype: bool

# %%
data[data['Runtime (Minutes)']>=180]
# Out:
#      Rank                    Title                   Genre  \
# 82     83  The Wolf of Wall Street  Biography,Comedy,Crime
# 88     89        The Hateful Eight     Crime,Drama,Mystery
# 311   312           La vie d'Adèle           Drama,Romance
#
#                                            Description             Director  \
# 82   Based on the true story of Jordan Belfort, fro...      Martin Scorsese
# 88   In the dead of a Wyoming winter, a bounty hunt...    Quentin Tarantino
# 311  Adèle's life is changed when she meets Emma, a...  Abdellatif Kechiche
#
#                                                 Actors  Year  \
# 82   Leonardo DiCaprio, Jonah Hill, Margot Robbie,M...  2013
# 88   Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  2015
# 311  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...  2013
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 82                 180     8.2  865134              116.87       75.0
# ...

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %% [markdown]
# # In Which Year There Was The Highest Voting?

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Votes']

# %%
data.groupby('Year')['Votes'].mean()
# Out:
# Year
# 2006    277232.219512
# 2007    266530.704545
# 2008    266580.145833
# 2009    267180.577778
# 2010    261082.929825
# 2011    259254.736842
# 2012    290861.483871
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
sns.barplot(x='Year',y='Votes',data=data) # Average votes per entry in each year
plt.title("Votes By Year")
plt.show()

# %%
data.groupby('Year')['Votes'].sum()
# Out:
# Year
# 2006    11366521
# 2007    11727351
# 2008    12795847
# 2009    12023126
# 2010    14881727
# 2011    14777520
# 2012    18033412
# 2013    18944679
# 2014    19709200
# 2015    14116879
# 2016    13550689
# Name: Votes, dtype: int64

# %%
data.groupby('Year')['Votes'].sum().sort_values(ascending=False)
# Out:
# Year
# 2014    19709200
# 2013    18944679
# 2012    18033412
# 2010    14881727
# 2011    14777520
# 2015    14116879
# 2016    13550689
# 2008    12795847
# 2009    12023126
# 2007    11727351
# 2006    11366521
# Name: Votes, dtype: int64

# %%
sns.barplot(x='Year', y='Votes', data=data, estimator=sum) # Total votes per year
plt.title("Votes By Year")
plt.show()

# %%
yearly_votes = data.groupby('Year')['Votes'].sum().reset_index()
# Before reset_index() → Year is like an index/label on the side
# After reset_index() → Year becomes a proper column in the table
sns.barplot(x='Year', y='Votes', data=yearly_votes)
# Out:
# <Axes: xlabel='Year', ylabel='Votes'>

# %% [markdown]
# # In Which Year There Was The Highest Revenue?

# %%
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %%
data.groupby('Year')['Revenue (Millions)'].sum().sort_values(ascending=False)
# Out:
# Year
# 2016    11002.09
# 2015     8799.09
# 2014     7945.33
# 2013     7399.11
# 2012     6826.39
# 2010     5989.65
# 2011     5341.09
# 2009     5208.39
# 2008     4681.22
# 2007     4095.26
# 2006     3577.48
# Name: Revenue (Millions), dtype: float64

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# # The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %%
data.groupby('Director')['Rating'].mean().sort_values()
# Out:
# Director
# Jason Friedberg                     1.90
# James Wong                          2.70
# George Nolfi                        3.90
# Joey Curtis                         4.00
# Sam Taylor-Johnson                  4.10
#                                     ...
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Christopher Nolan                   8.68
# Name: Rating, Length: 524, dtype: float64

# %%
data.nlargest(10, 'Rating')[['Title', 'Director', 'Rating']]
# Out:
#                      Title                          Director  Rating
# 54         The Dark Knight                 Christopher Nolan     9.0
# 80               Inception                 Christopher Nolan     8.8
# 36            Interstellar                 Christopher Nolan     8.6
# 96           Kimi no na wa                    Makoto Shinkai     8.6
# 249       The Intouchables                   Olivier Nakache     8.6
# 64            The Prestige                 Christopher Nolan     8.5
# 99            The Departed                   Martin Scorsese     8.5
# 124  The Dark Knight Rises                 Christopher Nolan     8.5
# 133               Whiplash                   Damien Chazelle     8.5
# 476    The Lives of Others  Florian Henckel von Donnersmarck     8.5

# %% [markdown]
# # Top 10 Lengthy Movies Title and Runtime

# %%
data.nlargest(10, 'Runtime (Minutes)')
# Out:
#      Rank                                     Title                     Genre  \
# 88     89                         The Hateful Eight       Crime,Drama,Mystery
# 82     83                   The Wolf of Wall Street    Biography,Comedy,Crime
# 311   312                            La vie d'Adèle             Drama,Romance
# 267   268                               Cloud Atlas              Drama,Sci-Fi
# 430   431                                  3 Idiots              Comedy,Drama
# 36     37                              Interstellar    Adventure,Drama,Sci-Fi
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 271   272         The Hobbit: An Unexpected Journey         Adventure,Fantasy
# 425   426       The Curious Case of Benjamin Button     Drama,Fantasy,Romance
# 126   127           Transformers: Age of Extinction   Action,Adventure,Sci-Fi
#
#                                            Description             Director  \
# ...

# %%
data.nlargest(10, 'Runtime (Minutes)')[['Title', 'Runtime (Minutes)']]
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %%
data.nlargest(10, 'Runtime (Minutes)')[['Title', 'Runtime (Minutes)']].set_index('Title')
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
top10_len=data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')
top10_len
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
sns.barplot(x='Runtime (Minutes)',y=top10_len.index, data=top10_len)
plt.title('Top 10 Lengtly Movies')
plt.show()

# %% [markdown]
# # Number of Movies Per Year

# %%
data['Year'].value_counts()
# Out:
# Year
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: count, dtype: int64

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")
plt.show()

# %% [markdown]
# # Most Popular Movie Title (Higest Revenue)

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Revenue (Millions)'].max()
# Out:
# 936.63

# %%
# data['Revenue (Millions)'].max() == data['Revenue (Millions)']
data['Revenue (Millions)'] == data['Revenue (Millions)'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993    False
# 994    False
# 996    False
# 997    False
# 999    False
# Name: Revenue (Millions), Length: 838, dtype: bool

# %%
data[ data['Revenue (Millions)'] == data['Revenue (Millions)'].max()]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# # Top 10 Highest Rated Movie Titles And its Directors

# %%
top_10=data.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')

# %%
top_10
# Out:
#                        Rating                          Director
# Title
# The Dark Knight           9.0                 Christopher Nolan
# Inception                 8.8                 Christopher Nolan
# Interstellar              8.6                 Christopher Nolan
# Kimi no na wa             8.6                    Makoto Shinkai
# The Intouchables          8.6                   Olivier Nakache
# The Prestige              8.5                 Christopher Nolan
# The Departed              8.5                   Martin Scorsese
# The Dark Knight Rises     8.5                 Christopher Nolan
# Whiplash                  8.5                   Damien Chazelle
# The Lives of Others       8.5  Florian Henckel von Donnersmarck

# %%
sns.barplot(x=top_10['Rating'], y=top_10.index, data=top_10)
plt.title("Top 10 Highest Rated Movie Titles")
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated Movie Titles')

# %%
sns.barplot(x=top_10['Rating'], y=top_10.index, data=top_10, hue='Director')
plt.title("Top 10 Highest Rated Movie Titles")
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated Movie Titles')

# %%
sns.barplot(x=top_10['Rating'], y=top_10.index, data=top_10, hue='Director', dodge=False)
plt.title("Top 10 Highest Rated Movie Titles")
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated Movie Titles')

# %%
sns.barplot(x=top_10['Rating'], y=top_10.index, data=top_10, hue='Director', dodge=False)
plt.legend(bbox_to_anchor=(1.05,1), loc=2)
plt.title("Top 10 Highest Rated Movie Titles")
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated Movie Titles')

# %% [markdown]
# # Top 10 Highest Revenue Movie Titles

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.sort_values(by='Revenue (Millions)',ascending=False).head()
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
# 87    88                                      Avatar
# 85    86                              Jurassic World
# 76    77                                The Avengers
# 54    55                             The Dark Knight
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
# 87  Action,Adventure,Fantasy
# 85   Action,Adventure,Sci-Fi
# 76             Action,Sci-Fi
# 54        Action,Crime,Drama
#
#                                           Description           Director  \
# 50  Three decades after the defeat of the Galactic...        J.J. Abrams
# 87  A paraplegic marine dispatched to the moon Pan...      James Cameron
# 85  A new theme park, built on the original site o...    Colin Trevorrow
# 76  Earth's mightiest heroes must come together an...        Joss Whedon
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
# ...

# %%
data.sort_values(by='Revenue (Millions)',ascending=False).head()['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# 87                                        Avatar
# 85                                Jurassic World
# 76                                  The Avengers
# 54                               The Dark Knight
# Name: Title, dtype: object

# %%
data.sort_values(by='Revenue (Millions)',ascending=False).head(10)['Title']
# Out:
# 50     Star Wars: Episode VII - The Force Awakens
# 87                                         Avatar
# 85                                 Jurassic World
# 76                                   The Avengers
# 54                                The Dark Knight
# 12                                      Rogue One
# 119                                  Finding Dory
# 94                        Avengers: Age of Ultron
# 124                         The Dark Knight Rises
# 578               The Hunger Games: Catching Fire
# Name: Title, dtype: object

# %%
top_10 = data.nlargest(10,'Revenue (Millions)')
top_10
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 87     88                                      Avatar
# 85     86                              Jurassic World
# 76     77                                The Avengers
# 54     55                             The Dark Knight
# 12     13                                   Rogue One
# 119   120                                Finding Dory
# 94     95                     Avengers: Age of Ultron
# 124   125                       The Dark Knight Rises
# 578   579             The Hunger Games: Catching Fire
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 87     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 76                Action,Sci-Fi
# 54           Action,Crime,Drama
# 12      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 94      Action,Adventure,Sci-Fi
# 124             Action,Thriller
# 578    Action,Adventure,Mystery
#
# ...

# %%
top_10['Title']
# Out:
# 50     Star Wars: Episode VII - The Force Awakens
# 87                                         Avatar
# 85                                 Jurassic World
# 76                                   The Avengers
# 54                                The Dark Knight
# 12                                      Rogue One
# 119                                  Finding Dory
# 94                        Avengers: Age of Ultron
# 124                         The Dark Knight Rises
# 578               The Hunger Games: Catching Fire
# Name: Title, dtype: object

# %%
top_10 = data.nlargest(10,'Revenue (Millions)')[['Title', 'Revenue (Millions)']].set_index('Title')

# %%
sns.barplot(x=top_10['Revenue (Millions)'], y=top_10.index, data=top_10)
plt.title("Top 10 Highest Revenue Movie Titles")
plt.show()

# %% [markdown]
# # Average Rating of Movies Year-wise

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Rating'].mean()
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
data1=data.groupby('Year')[['Year', 'Rating']].mean().sort_values(by='Rating', ascending=False).set_index('Year')

# %%
data1
# Out:
#           Rating
# Year
# 2006.0  7.143902
# 2007.0  7.140909
# 2011.0  6.945614
# 2012.0  6.933871
# 2009.0  6.911111
# 2010.0  6.894737
# 2013.0  6.832143
# 2014.0  6.822581
# 2008.0  6.708333
# 2015.0  6.674312
# 2016.0  6.644444

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=data1.index, y=data1['Rating'], data=data1)
plt.show()

# %% [markdown]
# # Does Rating Affect The Revenue?

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# # Answer : Yes

# %% [markdown]
# # Classify Movies Based on Ratings [Good,Better and Best]

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['Rating'].apply(rating)
# Out:
# 0      Excellent
# 1      Excellent
# 2      Excellent
# 3      Excellent
# 4           Good
#          ...
# 993      Average
# 994         Good
# 996      Average
# 997         Good
# 999      Average
# Name: Rating, Length: 838, dtype: object

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # Number of Action Movies

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
data['Genre'].str.contains('Action', case=False)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 993     True
# 994    False
# 996    False
# 997    False
# 999    False
# Name: Genre, Length: 838, dtype: bool

# %%
data[data['Genre'].str.contains('Action', case=False)]
# Out:
#      Rank                           Title                       Genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 954   955                      Death Race      Action,Sci-Fi,Thriller
# 956   957                          Legion       Action,Fantasy,Horror
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            Description            Director  \
# ...

# %%
len(data[data['Genre'].str.contains('Action', case=False)])
# Out:
# 277

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
# ...

# %%
data['temp']=list1

# %%
data.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore rating_cat  \
# 0     8.1  757074              333.13       76.0  Excellent
#
#                           temp
# 0  [Action, Adventure, Sci-Fi]

# %%
genre=input("Enter Genre you want to count : ").title()
count=0
for value in data['temp']:
    if genre in value:
        count=count+1
print("Total Count is",count)
# Out:
# Enter Genre you want to count :  Adventure
# Total Count is 244

# %% [markdown]
# # OR

# %%
len(data[data['Genre'].str.contains('action',case=False)])
# Out:
# 277

# %% [markdown]
# # Find Unique Values From Genre

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
uni_values=[]
for item in one_d:
    if item not in uni_values:
        uni_values.append(item)
uni_values
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Western',
#  'Crime',
#  'War',
#  'Musical',
#  'Sport']

# %%
len(uni_values)
# Out:
# 20

# %% [markdown]
# # How many Films of Each Genere Were Made?

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 419,
#          'Action': 277,
#          'Comedy': 250,
#          'Adventure': 244,
#          'Thriller': 148,
#          'Crime': 126,
#          'Romance': 120,
#          'Sci-Fi': 107,
#          'Fantasy': 92,
#          'Horror': 87,
#          'Mystery': 86,
#          'Biography': 67,
#          'Family': 48,
#          'Animation': 45,
#          'History': 25,
#          'Music': 15,
#          'Sport': 15,
#          'War': 10,
#          'Musical': 5,
#          'Western': 4})

# %% [markdown]
# # Predict Rating (Regression Model)

# %% [markdown]
# Features to use: Genre (encoded); Director (encoded); Actors (encoded); Runtime; Votes; Revenue; Metascore

# %% [markdown]
# ### Encoding Genre, Director, Actors

# %%
df = pd.get_dummies(data, columns=['Genre'], drop_first=True)

# %%
df
# Out:
#      Rank                     Title  \
# 0       1   Guardians of the Galaxy
# 1       2                Prometheus
# 2       3                     Split
# 3       4                      Sing
# 4       5             Suicide Squad
# ..    ...                       ...
# 993   994  Resident Evil: Afterlife
# 994   995                 Project X
# 996   997           Hostel: Part II
# 997   998    Step Up 2: The Streets
# 999  1000                Nine Lives
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df['Director'] = le.fit_transform(df['Director'])
df['Actors'] = le.fit_transform(df['Actors'])

# %%
df.head(2)
# Out:
#    Rank                    Title  \
# 0     1  Guardians of the Galaxy
# 1     2               Prometheus
#
#                                          Description  Director  Actors  Year  \
# 0  A group of intergalactic criminals are forced ...       208     156  2014
# 1  Following clues to the origin of mankind, a te...       417     612  2012
#
#    Runtime (Minutes)  Rating   Votes  Revenue (Millions)  ...  \
# 0                121     8.1  757074              333.13  ...
# 1                124     7.0  485820              126.46  ...
#
#    Genre_Horror,Mystery,Thriller Genre_Horror,Sci-Fi,Thriller  \
# 0                          False                        False
# 1                          False                        False
#
#   Genre_Horror,Thriller  Genre_Mystery,Romance,Sci-Fi  \
# 0                 False                         False
# 1                 False                         False
#
#    Genre_Mystery,Romance,Thriller  Genre_Mystery,Sci-Fi,Thriller  \
# ...

# %% [markdown]
# ### Preparing Test and Train Dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X = df.drop(['Rank', 'Title', 'Description', 'Year', 'temp', 'rating_cat'], axis=1)
y = df['Rating']

# %%
X.columns
# Out:
# Index(['Director', 'Actors', 'Runtime (Minutes)', 'Rating', 'Votes',
#        'Revenue (Millions)', 'Metascore', 'Genre_Action,Adventure',
#        'Genre_Action,Adventure,Biography', 'Genre_Action,Adventure,Comedy',
#        ...
#        'Genre_Horror,Mystery,Thriller', 'Genre_Horror,Sci-Fi,Thriller',
#        'Genre_Horror,Thriller', 'Genre_Mystery,Romance,Sci-Fi',
#        'Genre_Mystery,Romance,Thriller', 'Genre_Mystery,Sci-Fi,Thriller',
#        'Genre_Mystery,Thriller', 'Genre_Sci-Fi', 'Genre_Sci-Fi,Thriller',
#        'Genre_Thriller'],
#       dtype='object', length=195)

# %%
y
# Out:
# 0      8.1
# 1      7.0
# 2      7.3
# 3      7.2
# 4      6.2
#       ...
# 993    5.9
# 994    6.7
# 996    5.5
# 997    6.2
# 999    5.3
# Name: Rating, Length: 838, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# ### Train model

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Evaluate Model

# %%
from sklearn.metrics import mean_squared_error

preds = model.predict(X_test)

mse = mean_squared_error(y_test, preds)
rmse = mse ** 0.5

print("RMSE:", rmse)
# Out:
# RMSE: 0.11987702031665602
